# %%
# !pip install folium

# %%
import pandas as pd
import folium
file_path = './starbucks_20250411113957.csv'
data = pd.read_csv(file_path)
data = data[['이름','위도','경도','주소','타입']]
data.head()
# Out:
#         이름         위도          경도                                         주소  \
# 0  금정남산동DT  35.262179  129.091325         부산광역시 금정구 중앙대로 1989 (남산동)1522-3232
# 1   금정구청DT  35.238814  129.092986         부산광역시 금정구 중앙대로 1730 (부곡동)1522-3232
# 2   온천장역DT  35.224006  129.086560           부산광역시 금정구 식물원로 13 (장전동)1522-3232
# 3    부산대정문  35.232122  129.084496      부산광역시 금정구 부산대학로64번길 12 (장전동)1522-3232
# 4     부산대역  35.230522  129.088694  부산광역시 금정구 장전로12번길 64, 1~4층 (장전동)1522-3232
#
#               타입
# 0  pin_generalDT
# 1  pin_generalDT
# 2  pin_generalDT
# 3    pin_general
# 4    pin_general

# %%
fixdata = data[['이름','위도','경도']]
fixdata.head()
# Out:
#         이름         위도          경도
# 0  금정남산동DT  35.262179  129.091325
# 1   금정구청DT  35.238814  129.092986
# 2   온천장역DT  35.224006  129.086560
# 3    부산대정문  35.232122  129.084496
# 4     부산대역  35.230522  129.088694

# %%
coordinates = fixdata[['위도','경도']].to_numpy()
place = fixdata['이름'].to_numpy()

# 중심좌표 설정(기본위치)
center_lat, center_lon = 35.17574571 , 129.0817409

# 지도생성
m = folium.Map(location=[center_lat, center_lon], zoom_start=12)
store_type = data['타입']

for i, (lat, lon) in enumerate(coordinates):
    if store_type[i] == "pin_generalDT":
        ccolor = "blue"
        fcolor = "skyblue"
    elif store_type[i] == "pin_general":
        ccolor = "green"
        fcolor = "yellow"
    else:
        ccolor = "red"
        fcolor = "orange"
    folium.CircleMarker(
        location = [lat , lon],
        radious = 30,
        color = ccolor,
        fill = True,
        fill_color = fcolor,
        fill_opacity = 2,
        tooltip = place[i]
    ).add_to(m) # 지도 생성 후 원을 그리고 지도에 붙임

    folium.Marker(
        location = [lat + 0.001, lon],
        icon = folium.DivIcon(f'<div style="font-size: 9px; color: black; background-color: white; width:50px; white-space: nowrap; overflow:hidden; text-overflow: ellipsis; opactiy:0.7; border-radius:5px">{place[i]}</div>')
    ).add_to(m)
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_559c108adbc6edc63d749793a3804e20 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_559c108adbc6edc63d749793a3804e20&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_559c108adbc6edc63d749793a3804e20 = L.map(
#                 &quot;map_559c108adbc6edc63d749793a3804e20&quot;,
#                 {
#                     center: [35.17574571, 129.0817409],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_59f23aeedcb16d03c2daa7af788b8b05 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_59f23aeedcb16d03c2daa7af788b8b05.addTo(map_559c108adbc6edc63d749793a3804e20);
#
#
#             var circle_marker_2b16fecbfe10ac91da43754d6ab7a193 = L.circleMarker(
#                 [35.2621786292157, 129.091325043351],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;skyblue&quot;, &quot;fillOpacity&quot;: 2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_559c108adbc6edc63d749793a3804e20);
#
#
#             circle_marker_2b16fecbfe10ac91da43754d6ab7a193.bindTooltip(
#                 `&lt;div&gt;
#                      금정남산동DT
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_a777045284a7b6a7debb073441ea601c = L.marker(
#                 [35.263178629215695, 129.091325043351],
#                 {
# }
#             ).addTo(map_559c108adbc6edc63d749793a3804e20);
#
#
#             var div_icon_501c74dc1ac1911a6716bcdd0e8bbf65 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 9px; color: black; background-color: white; width:50px; white-space: nowrap; overflow:hidden; text-overflow: ellipsis; opactiy:0.7; border-radius:5px\&quot;\u003e\uae08\uc815\ub0a8\uc0b0\ub3d9DT\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_a777045284a7b6a7debb073441ea601c.setIcon(div_icon_501c74dc1ac1911a6716bcdd0e8bbf65);
#
#
#                 marker_a777045284a7b6a7debb073441ea601c.setIcon(div_icon_501c74dc1ac1911a6716bcdd0e8bbf65);
#
#
#             var circle_marker_da58e1ee074faca327189cc28ae0630b = L.circleMarker(
#                 [35.2388135211636, 129.092985849499],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;skyblue&quot;, &quot;fillOpacity&quot;: 2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_559c108adbc6edc63d749793a3804e20);
#
#
#             circle_marker_da58e1ee074faca327189cc28ae0630b.bindTooltip(
#                 `&lt;div&gt;
#                      금정구청DT
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_ac5157401b46bc18a6c7d9d71149f080 = L.marker(
#                 [35.2398135211636, 129.092985849499],
#                 {
# }
#             ).addTo(map_559c108adbc6edc63d749793a3804e20);
#
#
#             var div_icon_9ac471cdfc83e54c503d0b21d82b3a37 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 9px; color: black; background-color: white; width:50px; white-space: nowrap; overflow:hidden; text-overflow: ellipsis; opactiy:0.7; border-radius:5px\&quot;\u003e\uae08\uc815\uad6c\uccadDT\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_ac5157401b46bc18a6c7d9d71149f080.setIcon(div_icon_9ac471cdfc83e54c503d0b21d82b3a37);
#
#
#                 marker_ac5157401b46bc18a6c7d9d71149f080.setIcon(div_icon_9ac471cdfc83e54c503d0b21d82b3a37);
#
#
#             var circle_marker_3d97e482d6f7988b53b87820ab7d6aa9 = L.circleMarker(
#                 [35.224006, 129.08656],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;skyblue&quot;, &quot;fillOpacity&quot;: 2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: t
