# %%
import requests 
from bs4 import BeautifulSoup 
url = "https://www.melon.com/chart/index.htm"
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36 Edg/133.0.0.0'
}

response = requests.get(url, headers=headers)
if response.status_code == 200:
    soup = BeautifulSoup(response.content,"html.parser")
    song_titles = soup.select("div.ellipsis.rank01 a")
    artists = soup.select("div.ellipsis.rank02 span.checkEllipsis")
    for idx, (title, artist) in enumerate(zip(song_titles,artists), start=1):
        print(f"{idx}위: {title.text.strip()} - {artist.text.strip()}")
else: 
    print(f"페이지를 불러오는 데 실패했습니다. 상태 코드: {response.status_code}")
# Out:
# 1위: REBEL HEART - IVE (아이브)
# 2위: HOME SWEET HOME (feat. 태양, 대성) - G-DRAGON
# 3위: 나는 반딧불 - 황가람
# 4위: Whiplash - aespa
# 5위: APT. - 로제 (ROSÉ), Bruno Mars
# 6위: Drowning - WOODZ
# 7위: 오늘만 I LOVE YOU - BOYNEXTDOOR
# 8위: ATTITUDE - IVE (아이브)
# 9위: toxic till the end - 로제 (ROSÉ)
# 10위: Dash - PLAVE
# 11위: POWER - G-DRAGON
# 12위: HAPPY - DAY6 (데이식스)
# 13위: 모르시나요(PROD.로코베리) - 조째즈
# 14위: 내게 사랑이 뭐냐고 물어본다면 - 로이킴
# 15위: DRIP - BABYMONSTER
# 16위: RIZZ - PLAVE
# 17위: Chroma Drift - PLAVE
# 18위: Island - PLAVE
# 19위: 소나기 - 이클립스 (ECLIPSE)
# 20위: Supernova - aespa
# 21위: 너와의 모든 지금 - 재쓰비 (JAESSBEE)
# 22위: 12:32 (A to T) - PLAVE
# 23위: 천상연 - 이창섭
# 24위: Welcome to the Show - DAY6 (데이식스)
# 25위: UP (KARINA Solo) - aespa
# 26위: 한 페이지가 될 수 있게 - DAY6 (데이식스)
# 27위: 내 이름 맑음 - QWER
# 28위: 사랑은 늘 도망가 - 임영웅
# 29위: 슬픈 초대장 - 순순희(지환)
# 30위: 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지 - AKMU (악뮤)
# 31위: Love wins all - 아이유
# 32위: 고민중독 - QWER
# 33위: Mantra - 제니 (JENNIE)
# 34위: 예뻤어 - DAY6 (데이식스)
# 35위: How Sweet - NewJeans
# 36위: 첫 만남은 계획대로 되지 않아 - TWS (투어스)
# 37위: 너의 모든 순간 - 성시경
# 38위: Supersonic - 프로미스나인
# 39위: Die With A Smile - Lady Gaga, Bruno Mars
# 40위: 우리들의 블루스 - 임영웅
# 41위: 나는 아픈 건 딱 질색이니까 - (여자)아이들
# 42위: 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection)) - 너드커넥션 (Nerd Connection)
# 43위: 온기 - 임영웅
# 44위: 비의 랩소디 - 임재현
# 45위: I AM - IVE (아이브)
# 46위: 무제(無題) (Untitled, 2014) - G-DRAGON
# 47위: Small girl (feat. 도경수(D.O.)) - 이영지
# 48위: Home - 임영웅
# 49위: 에피소드 - 이무진
# 50위: 미안해 미워해 사랑해 - Crush
# 51위: 모래 알갱이 - 임영웅
# 52위: 모든 날, 모든 순간 (Every day, Every Moment) - 폴킴
# 53위: Magnetic - 아일릿(ILLIT)
# 54위: 헤어지자 말해요 - 박재정
# 55위: 다시 만날 수 있을까 - 임영웅
# 56위: 다정히 내 이름을 부르면 - 경서예지, 전건호
# 57위: number one girl - 로제 (ROSÉ)
# 58위: 이제 나만 믿어요 - 임영웅
# 59위: Ditto - NewJeans
# 60위: Hype Boy - NewJeans
# 61위: 청춘만화 - 이무진
# 62위: 인사 - 범진
# 63위: 청혼하지 않을 이유를 못 찾았어 - 이무진
# 64위: Armageddon - aespa
# 65위: 미치게 그리워서 - 황가람
# 66위: 해야 (HEYA) - IVE (아이브)
# 67위: 무지개 - 임영웅
# 68위: 사랑인가 봐 - 멜로망스
# 69위: 살기 위해서 - 순순희
# 70위: 주저하는 연인들을 위해 - 잔나비
# 71위: Do or Die - 임영웅
# 72위: Igloo - KISS OF LIFE
# 73위: Sticky - KISS OF LIFE
# 74위: Supernatural - NewJeans
# 75위: London Boy - 임영웅
# 76위: Boom Boom Bass - RIIZE
# 77위: 클락션 (Klaxon) - (여자)아이들
# 78위: Seven (feat. Latto) - Clean Ver. - 정국
# 79위: 취중고백 - 김민석
# 80위: 눈이 오잖아(Feat.헤이즈) - 이무진
# 81위: Hug (포옹) - RIIZE
# 82위: 인생찬가 - 임영웅
# 83위: Polaroid - 임영웅
# 84위: Love 119 - RIIZE
# 85위: 녹아내려요 - DAY6 (데이식스)
# 86위: To. X - 태연 (TAEYEON)
# 87위: SPOT! (feat. JENNIE) - 지코 (ZICO)
# 88위: 사막에서 꽃을 피우듯 - 우디 (Woody)
# 89위: Bubble Gum - NewJeans
# 90위: 청바지 - 부석순 (SEVENTEEN)
# 91위: 사건의 지평선 - 윤하 (YOUNHA)
# 92위: 봄여름가을겨울 (Still Life) - BIGBANG (빅뱅)
# 93위: 첫 눈 - EXO
# 94위: Congratulations - DAY6 (데이식스)
# 95위: Drama - aespa
# 96위: 봄날 - 방탄소년단
# 97위: 연애편지 - 임영웅
# 98위: Dynamite - 방탄소년단
# 99위: earthquake - 지수 (JISOO)
# 100위: 보금자리 - 임영웅

# %%
import requests
import json

url = "http://kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=86c5204088a51e4d9a9e26141ed5b4e5&targetDt=20250216"
res = requests.get(url)
text = res.text

d = json.loads(text)

for b in d['boxOfficeResult']['dailyBoxOfficeList']:
    print(b['rank'],b['movieNm'],b['audiCnt'])
# Out:
# 1 캡틴 아메리카: 브레이브 뉴 월드 211266
# 2 말할 수 없는 비밀 30006
# 3 히트맨2 25480
# 4 명탐정 코난: 14번째 표적 10468
# 5 서브스턴스 7238
# 6 검은 수녀들 6421
# 7 엘리: 몬스터 패밀리 5660
# 8 브루탈리스트 5576
# 9 더 폴: 디렉터스 컷 4798
# 10 아이유 콘서트 : 더 위닝 2744

# %%
import requests as req
from bs4 import BeautifulSoup as bs
url = "https://www.pusan.ac.kr/kor/CMS/MenuMgr/menuListOnBuilding.do?mCode=MN202"
headers = {'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36 Edg/133.0.0.0'}
web = req.get(url, headers = headers)
soup = bs(web.content, 'html5lib')
menucard = soup.select('.menu-tb1')
won = soup.select('.menu-tit01')
menu = soup.select('h3.menu-tit01+p')
day = soup.select('.day')
date = soup.select('.date')
for d, dd, w, m in zip(day, date, won, menu):
    print('='*15)
    print(d.text, dd.text)
    print(w.text+'\n'+m.text)
    print('='*15)
# Out:
# ===============
# 월 2025.02.17
# 정식-5,500원
# 강황밥
# 김치콩나물국
# 돈육바싹불고기
# 모듬잡채
# 멸치새우견과볶음
# 상추겉절이
# 포기김치
#
# ===============
# ===============
# 화 2025.02.18
# 정식-5,500원
# 백미밥
# 물만두국
# 순살닭매콤조림
# 쫄면야채무침
# 파래무무침
# 참나물겉절이
# 포기김치
#
# ===============
# ===============
# 수 2025.02.19
# 정식-5,500원
# 백미밥
# 모듬어묵국
# 함박스테이크/치즈/소스
# 스파게티/소스
# 치커리유자청샐러드
# 콩나물무침
# 포기김치
#
# ===============
# ===============
# 목 2025.02.20
# 정식-5,500원
# 잡곡밥
# 홍합미역국
# 순살치킨/맛초킹소스
# 꼬시레기두부무침
# 잡채어묵조림
# 상추겉절이
# 포기김치
#
# ===============
# ===============
# 금 2025.02.21
# 정식-5,500원
# 백미밥
# 국수
# 깐풍기/소스
# 알감자버터구이
# 도토리묵김치무침
# 열무겉절이
# 포기김치
#
# ===============

# %%
import requests as req
from bs4 import BeautifulSoup as bs
url = "https://music.bugs.co.kr/chart?wl_ref=M_left_02_01"
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36 Edg/133.0.0.0'}
web = req.get(url, headers = headers)
soup = bs(web.content, 'html.parser')
title = soup.select('p.title')
artist = soup.select('p.artist')
for i, (t,a) in enumerate(zip(title,artist),1):
    print(f"{i}순위 {t.text.strip()} = {a.text.strip()}")
# Out:
# 1순위 REBEL HEART = IVE (아이브)
# 2순위 ATTITUDE = IVE (아이브)
# 3순위 APT. = 로제(ROSÉ)
#
#
# 로제(ROSÉ)
# 4순위 HOME SWEET HOME (feat. 태양, 대성) = G-DRAGON
# 5순위 Drowning = WOODZ
# 6순위 Whiplash = aespa
# 7순위 나는 반딧불 = 황가람
# 8순위 toxic till the end = 로제(ROSÉ)
# 9순위 오늘만 I LOVE YOU = BOYNEXTDOOR
# 10순위 HAPPY = DAY6 (데이식스)
# 11순위 Die With A Smile = Lady GaGa(레이디 가가)
#
#
# Lady GaGa(레이디 가가)
# 12순위 Love Hangover (feat. Dominic Fike) = 제니 (JENNIE)
#
#
# 제니 (JENNIE)
# 13순위 POWER = G-DRAGON
# 14순위 Mantra = 제니 (JENNIE)
# 15순위 너와의 모든 지금 = 재쓰비 (JAESSBEE)
# 16순위 DRIP = BABYMONSTER
# 17순위 Supernova = aespa
# 18순위 고민중독 = QWER
# 19순위 한 페이지가 될 수 있게 = DAY6 (데이식스)
# 20순위 내 이름 맑음 = QWER
# 21순위 UP (KARINA Solo) = aespa
# 22순위 내게 사랑이 뭐냐고 물어본다면 = 로이킴
# 23순위 number one girl = 로제(ROSÉ)
# 24순위 모르시나요(PROD.로코베리) = 조째즈
# 25순위 Welcome to the Show = DAY6 (데이식스)
# 26순위 earthquake = 지수(JISOO)
# 27순위 How Sweet = NewJeans
# 28순위 Supernatural = NewJeans
# 29순위 청춘만화 = 이무진
# 30순위 첫 만남은 계획대로 되지 않아 = TWS (투어스)
# 31순위 luther = Kendrick Lamar(켄드릭 라마)
#
#
# Kendrick Lamar(켄드릭 라마)
# 32순위 소나기 = 이클립스 (ECLIPSE)
# 33순위 Armageddon = aespa
# 34순위 녹아내려요 = DAY6 (데이식스)
# 35순위 에피소드 = 이무진
# 36순위 Love wins all = 아이유(IU)
# 37순위 Hug (포옹) = RIIZE
# 38순위 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지 = AKMU(악뮤)
# 39순위 나는 아픈 건 딱 질색이니까 = (여자)아이들
# 40순위 Magnetic = 아일릿(ILLIT)
# 41순위 모든 날, 모든 순간 (Every day, Every Moment) = 폴킴(Paul Kim)
# 42순위 Letter To Myself = 태연 (TAEYEON)
# 43순위 Hype Boy = NewJeans
# 44순위 Igloo = KISS OF LIFE
# 45순위 I AM = IVE (아이브)
# 46순위 Ditto = NewJeans
# 47순위 천상연 = 이창섭
# 48순위 Small girl (feat. 도경수(D.O.)) = 이영지
# 49순위 주저하는 연인들을 위해 = 잔나비
# 50순위 예뻤어 = DAY6 (데이식스)
# 51순위 헤어지자 말해요 = 박재정
# 52순위 너의 모든 순간 = 성시경
# 53순위 Bubble Gum = NewJeans
# 54순위 밤양갱 = 비비(BIBI)
# 55순위 무제(無題) (Untitled, 2014) = G-DRAGON
# 56순위 슬픈 초대장 = 순순희 (지환)
# 57순위 Cruel Summer = Taylor Swift(테일러 스위프트)
# 58순위 Attention = NewJeans
# 59순위 LOVE DIVE = IVE (아이브)
# 60순위 Sticky = KISS OF LIFE
# 61순위 미치게 그리워서 = 황가람
# 62순위 To. X = 태연 (TAEYEON)
# 63순위 Supersonic = 프로미스나인
# 64순위 Congratulations = DAY6 (데이식스)
# 65순위 Love me or Leave me = DAY6 (데이식스)
# 66순위 Boom Boom Bass = RIIZE
# 67순위 비의 랩소디 = 임재현
# 68순위 Not Like Us = Kendrick Lamar(켄드릭 라마)
# 69순위 우리의 다정한 계절 속에 (Season of Memories) = 여자친구(GFRIEND)
# 70순위 숲 = 최유리
# 71순위 해야 (HEYA) = IVE (아이브)
# 72순위 ETA = NewJeans
# 73순위 사건의 지평선 = 윤하(Younha/ユンナ)
# 74순위 Dash = PLAVE
# 75순위 인사 = 범진
# 76순위 Drama = aespa
# 77순위 내가 S면 넌 나의 N이 되어줘 = TWS (투어스)
# 78순위 내가 널 지켜줄게 = 폴킴(Paul Kim)
# 79순위 Spicy = aespa
# 80순위 After LIKE = IVE (아이브)
# 81순위 네모네모 = YENA (최예나)
# 82순위 청바지 = 부석순(SEVENTEEN)
# 83순위 MEOW = MEOVV (미야오)
# 84순위 Live My Life = aespa
# 85순위 사랑인가 봐 = 멜로망스(MeloMance)
# 86순위 Cherish (My Love) = 아일릿(ILLIT)
# 87순위 drinks or coffee = 로제(ROSÉ)
# 88순위 청혼하지 않을 이유를 못 찾았어 = 이무진
# 89순위 아직 거기 살아 = DAY6 (데이식스)
# 90순위 SPOT! (feat. JENNIE) = 지코 (ZICO)
# 91순위 Super Shy = NewJeans
# 92순위 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection)) = 너드커넥션(Nerd Connection)
# 93순위 Girls Never Die = tripleS (트리플에스)
# 94순위 미안해 미워해 사랑해 = Crush
# 95순위 Dangerously = Charlie Puth(찰리 푸스)
# 96순위 살기 위해서 = 순순희
# 97순위 Storm = 김보경 (NEON)
# 98순위 The Stranger = 온앤오프(ONF)
# 99순위 사랑은 늘 도망가 = 임영웅
# 100순위 클락션 (Klaxon) = (여자)아이들
