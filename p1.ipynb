# %%
import requests 
from bs4 import BeautifulSoup 
url = "https://www.melon.com/chart/index.htm"
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36 Edg/133.0.0.0'
}

response = requests.get(url, headers=headers)
if response.status_code == 200:
    soup = BeautifulSoup(response.content,"html.parser")
    song_titles = soup.select("div.ellipsis.rank01 a")
    artists = soup.select("div.ellipsis.rank02 span.checkEllipsis")
    for idx, (title, artist) in enumerate(zip(song_titles,artists), start=1):
        print(f"{idx}위: {title.text.strip()} - {artist.text.strip()}")
else: 
    print(f"페이지를 불러오는 데 실패했습니다. 상태 코드: {response.status_code}")
# Out:
# 1위: REBEL HEART - IVE (아이브)
# 2위: HOME SWEET HOME (feat. 태양, 대성) - G-DRAGON
# 3위: 나는 반딧불 - 황가람
# 4위: Whiplash - aespa
# 5위: APT. - 로제 (ROSÉ), Bruno Mars
# 6위: Drowning - WOODZ
# 7위: ATTITUDE - IVE (아이브)
# 8위: 오늘만 I LOVE YOU - BOYNEXTDOOR
# 9위: Dash - PLAVE
# 10위: toxic till the end - 로제 (ROSÉ)
# 11위: 모르시나요(PROD.로코베리) - 조째즈
# 12위: POWER - G-DRAGON
# 13위: RIZZ - PLAVE
# 14위: HAPPY - DAY6 (데이식스)
# 15위: Chroma Drift - PLAVE
# 16위: 내게 사랑이 뭐냐고 물어본다면 - 로이킴
# 17위: Island - PLAVE
# 18위: 12:32 (A to T) - PLAVE
# 19위: 사랑은 늘 도망가 - 임영웅
# 20위: DRIP - BABYMONSTER
# 21위: 소나기 - 이클립스 (ECLIPSE)
# 22위: 너와의 모든 지금 - 재쓰비 (JAESSBEE)
# 23위: Supernova - aespa
# 24위: 천상연 - 이창섭
# 25위: Welcome to the Show - DAY6 (데이식스)
# 26위: 우리들의 블루스 - 임영웅
# 27위: 온기 - 임영웅
# 28위: 한 페이지가 될 수 있게 - DAY6 (데이식스)
# 29위: UP (KARINA Solo) - aespa
# 30위: 내 이름 맑음 - QWER
# 31위: Home - 임영웅
# 32위: 슬픈 초대장 - 순순희(지환)
# 33위: 모래 알갱이 - 임영웅
# 34위: 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지 - AKMU (악뮤)
# 35위: 다시 만날 수 있을까 - 임영웅
# 36위: 이제 나만 믿어요 - 임영웅
# 37위: Love wins all - 아이유
# 38위: Do or Die - 임영웅
# 39위: 무지개 - 임영웅
# 40위: 고민중독 - QWER
# 41위: London Boy - 임영웅
# 42위: 예뻤어 - DAY6 (데이식스)
# 43위: Mantra - 제니 (JENNIE)
# 44위: Die With A Smile - Lady Gaga, Bruno Mars
# 45위: 인생찬가 - 임영웅
# 46위: Polaroid - 임영웅
# 47위: How Sweet - NewJeans
# 48위: 너의 모든 순간 - 성시경
# 49위: 첫 만남은 계획대로 되지 않아 - TWS (투어스)
# 50위: 나는 아픈 건 딱 질색이니까 - (여자)아이들
# 51위: 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection)) - 너드커넥션 (Nerd Connection)
# 52위: 미치게 그리워서 - 황가람
# 53위: 연애편지 - 임영웅
# 54위: Supersonic - 프로미스나인
# 55위: 무제(無題) (Untitled, 2014) - G-DRAGON
# 56위: I AM - IVE (아이브)
# 57위: 비의 랩소디 - 임재현
# 58위: 에피소드 - 이무진
# 59위: Small girl (feat. 도경수(D.O.)) - 이영지
# 60위: 미안해 미워해 사랑해 - Crush
# 61위: 모든 날, 모든 순간 (Every day, Every Moment) - 폴킴
# 62위: 보금자리 - 임영웅
# 63위: 청춘만화 - 이무진
# 64위: 헤어지자 말해요 - 박재정
# 65위: 다정히 내 이름을 부르면 - 경서예지, 전건호
# 66위: number one girl - 로제 (ROSÉ)
# 67위: Magnetic - 아일릿(ILLIT)
# 68위: 청혼하지 않을 이유를 못 찾았어 - 이무진
# 69위: 살기 위해서 - 순순희
# 70위: Ditto - NewJeans
# 71위: 인사 - 범진
# 72위: Hype Boy - NewJeans
# 73위: Armageddon - aespa
# 74위: 해야 (HEYA) - IVE (아이브)
# 75위: 주저하는 연인들을 위해 - 잔나비
# 76위: 사랑인가 봐 - 멜로망스
# 77위: Seven (feat. Latto) - Clean Ver. - 정국
# 78위: Igloo - KISS OF LIFE
# 79위: Hug (포옹) - RIIZE
# 80위: 취중고백 - 김민석
# 81위: 눈이 오잖아(Feat.헤이즈) - 이무진
# 82위: Supernatural - NewJeans
# 83위: 청바지 - 부석순 (SEVENTEEN)
# 84위: Sticky - KISS OF LIFE
# 85위: 클락션 (Klaxon) - (여자)아이들
# 86위: 녹아내려요 - DAY6 (데이식스)
# 87위: To. X - 태연 (TAEYEON)
# 88위: Love 119 - RIIZE
# 89위: earthquake - 지수 (JISOO)
# 90위: 사막에서 꽃을 피우듯 - 우디 (Woody)
# 91위: 봄여름가을겨울 (Still Life) - BIGBANG (빅뱅)
# 92위: Boom Boom Bass - RIIZE
# 93위: SPOT! (feat. JENNIE) - 지코 (ZICO)
# 94위: 사건의 지평선 - 윤하 (YOUNHA)
# 95위: 봄날 - 방탄소년단
# 96위: 첫 눈 - EXO
# 97위: Dynamite - 방탄소년단
# 98위: Bubble Gum - NewJeans
# 99위: Congratulations - DAY6 (데이식스)
# 100위: Drama - aespa

# %%
import requests
import json

url = "http://kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=86c5204088a51e4d9a9e26141ed5b4e5&targetDt=20250216"
res = requests.get(url)
text = res.text

d = json.loads(text)

for b in d['boxOfficeResult']['dailyBoxOfficeList']:
    print(b['rank'],b['movieNm'],b['audiCnt'])
# Out:
# 1 캡틴 아메리카: 브레이브 뉴 월드 211266
# 2 말할 수 없는 비밀 30006
# 3 히트맨2 25480
# 4 명탐정 코난: 14번째 표적 10468
# 5 서브스턴스 7238
# 6 검은 수녀들 6421
# 7 엘리: 몬스터 패밀리 5660
# 8 브루탈리스트 5576
# 9 더 폴: 디렉터스 컷 4798
# 10 아이유 콘서트 : 더 위닝 2744

# %%
import requests as req
from bs4 import BeautifulSoup as bs
url = "https://www.pusan.ac.kr/kor/CMS/MenuMgr/menuListOnBuilding.do?mCode=MN202"
headers = {'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36 Edg/133.0.0.0'}
web = req.get(url, headers = headers)
soup = bs(web.content, 'html5lib')
menucard = soup.select('.menu-tb1')
won = soup.select('.menu-tit01')
menu = soup.select('h3.menu-tit01+p')
day = soup.select('.day')
date = soup.select('.date')
for d, dd, w, m in zip(day, date, won, menu):
    print('='*15)
    print(d.text, dd.text)
    print(w.text+'\n'+m.text)
    print('='*15)
# Out:
# ===============
# 월 2025.02.17
# 정식-5,500원
# 강황밥
# 김치콩나물국
# 돈육바싹불고기
# 모듬잡채
# 멸치새우견과볶음
# 상추겉절이
# 포기김치
#
# ===============
# ===============
# 화 2025.02.18
# 정식-5,500원
# 백미밥
# 물만두국
# 순살닭매콤조림
# 쫄면야채무침
# 파래무무침
# 참나물겉절이
# 포기김치
#
# ===============
# ===============
# 수 2025.02.19
# 정식-5,500원
# 백미밥
# 모듬어묵국
# 함박스테이크/치즈/소스
# 스파게티/소스
# 치커리유자청샐러드
# 콩나물무침
# 포기김치
#
# ===============
# ===============
# 목 2025.02.20
# 정식-5,500원
# 잡곡밥
# 홍합미역국
# 순살치킨/맛초킹소스
# 꼬시레기두부무침
# 잡채어묵조림
# 상추겉절이
# 포기김치
#
# ===============
# ===============
# 금 2025.02.21
# 정식-5,500원
# 백미밥
# 국수
# 깐풍기/소스
# 알감자버터구이
# 도토리묵김치무침
# 열무겉절이
# 포기김치
#
# ===============
